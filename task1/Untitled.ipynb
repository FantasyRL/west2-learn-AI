# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
from random import randint
def sayHello(any):
   print ('hello world!%s' %any)
# name=input()
# if name=="hello":
#     print("world")
# if name=="foo":
#     print(randint(5, 10))
# for i in range (1,5):
#     print(i)
str1 = 'good'
str2 = "bye"
print(str1+str2)
print("%s's score is %d" % ('Mike', 87))

a = "1"
print(a, type(a))
sayHello("a")
# error wrap
# try:
#    f = open('non-exist.txt')
#    print ('File opened!')
#    f.close()
# except:
#    print ('File not exists.')

class MyClass:
    name = ''
    pwd = ''
    def __init__(self):
        self.name = ""
        self.pwd = ""
    def setName(self, name):
        self.name = name

mc = MyClass()      # 不要调用 __init__()
mc.setName('hello')
mc.pwd = 'world'
print(mc.name, mc.pwd)

lst1 = (1,2,3,4,5,6)
lst2=map(lambda x:x*2,lst1)
print(list(lst2))
# Out:
# goodbye
# Mike's score is 87
# 1 <class 'str'>
# hello world!a
# hello world
# [2, 4, 6, 8, 10, 12]
